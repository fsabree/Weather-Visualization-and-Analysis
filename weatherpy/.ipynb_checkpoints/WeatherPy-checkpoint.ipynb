# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Read Output File (CSV) - only run if not running for the 1st time.  This keeps from going back to the API for additional changed data.
#city_weather_df = pd.read_csv("./cities.csv")
#city_weather_df.head()
# Out:
#    Unnamed: 0            city   temp  cloudiness country          date  \
# 0           0       jamestown  44.83        75.0      US  1.586232e+09
# 1           1          dikson  -2.18        52.0      RU  1.586233e+09
# 2           2     bandarbeyla  78.80         0.0      SO  1.586233e+09
# 3           3           pital  70.14        91.0      CO  1.586233e+09
# 4           4  port elizabeth  57.20        60.0      ZA  1.586233e+09
#
#    humidity    lat    lng  max temp  wind speed
# 0      26.0  42.10 -79.24     48.00        1.34
# 1      92.0  73.51  80.55     -2.18        9.55
# 2      67.0   9.49  50.81     78.80        5.21
# 3      59.0   2.27 -75.80     70.14        1.45
# 4      47.0 -33.92  25.57     57.20       23.04

# %% [markdown]
# ## Generate Cities List

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 594

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
weather_url = "http://api.openweathermap.org/data/2.5/weather?q="
units =  "Imperial"

# Build query URL based on current element in units
#query_url = weather_url + city + "&appid=" + weather_api_key+ "&units=" + units

temp = []
cld = []
country = []
date = []
hum = []
lat = []
lng = []
mtemp = []
wspeed = []

print("Beginning Data Retrieval")
print("-"*50)   
for city in cities:
    try:
        response = requests.get(weather_url + city + "&appid=" + weather_api_key+ "&units=" + units).json()
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        cld.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        hum.append(response['main']['humidity'])
        lng.append(response['coord']['lon'])
        mtemp.append(response['main']['temp_max'])
        wspeed.append(response['wind']['speed'])
       # Add a one second interval between queries to stay within API query limits
        time.sleep(1)
        print(f'Processing Record {cities.index(city)+1} of set 1 |{city}')
    except(KeyError):
        print("Skipping city...")

print("-"*50) 
print("Data Retrieval Complete")
print("-"*50)
# Out:
# Beginning Data Retrieval
# --------------------------------------------------
# Processing Record 1 of set 1 |jamestown
# Processing Record 2 of set 1 |dikson
# Processing Record 3 of set 1 |bandarbeyla
# Processing Record 4 of set 1 |pital
# Processing Record 5 of set 1 |port elizabeth
# Processing Record 6 of set 1 |geraldton
# Processing Record 7 of set 1 |busselton
# Processing Record 8 of set 1 |mataura
# Processing Record 9 of set 1 |asosa
# Processing Record 10 of set 1 |waingapu
# Processing Record 11 of set 1 |tuktoyaktuk
# Processing Record 12 of set 1 |mehamn
# Processing Record 13 of set 1 |ushuaia
# Skipping city...
# Processing Record 15 of set 1 |parakou
# Processing Record 16 of set 1 |mahebourg
# Skipping city...
# Processing Record 18 of set 1 |homer
# Processing Record 19 of set 1 |mayor pablo lagerenza
# Processing Record 20 of set 1 |vaini
# Processing Record 21 of set 1 |baruun-urt
# Processing Record 22 of set 1 |punta arenas
# Processing Record 23 of set 1 |omis
# Processing Record 24 of set 1 |severo-kurilsk
# Processing Record 25 of set 1 |hobart
# Processing Record 26 of set 1 |bengkulu
# Processing Record 27 of set 1 |guerrero negro
# Processing Record 28 of set 1 |namwala
# Processing Record 29 of set 1 |bonnyville
# Processing Record 30 of set 1 |kuala terengganu
# Processing Record 31 of set 1 |hasaki
# Skipping city...
# Processing Record 33 of set 1 |bilma
# Processing Record 34 of set 1 |albany
# Processing Record 35 of set 1 |new norfolk
# Processing Record 36 of set 1 |lompoc
# Processing Record 37 of set 1 |rawson
# Skipping city...
# Processing Record 39 of set 1 |isangel
# Processing Record 40 of set 1 |marathon
# Skipping city...
# Processing Record 42 of set 1 |hilo
# Processing Record 43 of set 1 |maniitsoq
# Processing Record 44 of set 1 |tasiilaq
# Processing Record 45 of set 1 |atar
# Processing Record 46 of set 1 |vagur
# Processing Record 47 of set 1 |praia da vitoria
# Processing Record 48 of set 1 |bluff
# Processing Record 49 of set 1 |klaksvik
# Processing Record 50 of set 1 |georgetown
# Processing Record 51 of set 1 |krasnoselkup
# Processing Record 52 of set 1 |atuona
# Processing Record 53 of set 1 |avarua
# Processing Record 54 of set 1 |bethel
# Processing Record 55 of set 1 |yelan
# Skipping city...
# Processing Record 57 of set 1 |fairbanks
# Processing Record 58 of set 1 |bambous virieux
# Processing Record 59 of set 1 |dunedin
# Processing Record 60 of set 1 |tubuala
# Processing Record 61 of set 1 |barrow
# Processing Record 62 of set 1 |tuy hoa
# Skipping city...
# Processing Record 64 of set 1 |chapais
# Processing Record 65 of set 1 |ballina
# Processing Record 66 of set 1 |bredasdorp
# Skipping city...
# Processing Record 68 of set 1 |lincoln
# Processing Record 69 of set 1 |raymondville
# Skipping city...
# Processing Record 71 of set 1 |qaanaaq
# Processing Record 72 of set 1 |qaqortoq
# Processing Record 73 of set 1 |mar del plata
# Processing Record 74 of set 1 |carnarvon
# Processing Record 75 of set 1 |botou
# Processing Record 76 of set 1 |rikitea
# Processing Record 77 of set 1 |medina
# Processing Record 78 of set 1 |sinnamary
# Processing Record 79 of set 1 |port alfred
# Processing Record 80 of set 1 |hermanus
# Processing Record 81 of set 1 |kribi
# Processing Record 82 of set 1 |ilulissat
# Skipping city...
# Processing Record 84 of set 1 |oyama
# Processing Record 85 of set 1 |kaikalur
# Processing Record 86 of set 1 |cayenne
# Skipping city...
# Processing Record 88 of set 1 |puerto ayora
# Processing Record 89 of set 1 |palmerston
# Processing Record 90 of set 1 |rock springs
# Processing Record 91 of set 1 |leningradskiy
# Processing Record 92 of set 1 |cidreira
# Processing Record 93 of set 1 |saskylakh
# Processing Record 94 of set 1 |yellowknife
# Processing Record 95 of set 1 |jumla
# Processing Record 96 of set 1 |totma
# Processing Record 97 of set 1 |kodiak
# Skipping city...
# Processing Record 99 of set 1 |tessalit
# Processing Record 100 of set 1 |timmins
# Processing Record 101 of set 1 |camacha
# Processing Record 102 of set 1 |chokurdakh
# Processing Record 103 of set 1 |thompson
# Processing Record 104 of set 1 |batticaloa
# Processing Record 105 of set 1 |makakilo city
# Processing Record 106 of set 1 |adeje
# Processing Record 107 of set 1 |upernavik
# Processing Record 108 of set 1 |aykhal
# Processing Record 109 of set 1 |falmouth
# Processing Record 110 of set 1 |kloulklubed
# Processing Record 111 of set 1 |fortuna
# Processing Record 112 of set 1 |butaritari
# Skipping city...
# Skipping city...
# Processing Record 115 of set 1 |tuatapere
# Processing Record 116 of set 1 |nikolskoye
# Processing Record 117 of set 1 |esperance
# Processing Record 118 of set 1 |alofi
# Processing Record 119 of set 1 |cape town
# Processing Record 120 of set 1 |la ronge
# Processing Record 121 of set 1 |vila franca do campo
# Processing Record 122 of set 1 |namibe
# Processing Record 123 of set 1 |shimoda
# Processing Record 124 of set 1 |lebu
# Processing Record 125 of set 1 |herat
# Processing Record 126 of set 1 |faanui
# Processing Record 127 of set 1 |jieshi
# Processing Record 128 of set 1 |nantucket
# Processing Record 129 of set 1 |khatanga
# Processing Record 130 of set 1 |majene
# Processing Record 131 of set 1 |hualmay
# Processing Record 132 of set 1 |ankazoabo
# Processing Record 133 of set 1 |kapaa
# Processing Record 134 of set 1 |ponta do sol
# Processing Record 135 of set 1 |reykjavik
# Processing Record 136 of set 1 |la palma
# Processing Record 137 of set 1 |rocha
# Processing Record 138 of set 1 |salinopolis
# Processing Record 139 of set 1 |cherskiy
# Processing Record 140 of set 1 |saint-augustin
# Processing Record 141 of set 1 |torrington
# Processing Record 142 of set 1 |carndonagh
# Processing Record 143 of set 1 |birao
# Processing Record 144 of set 1 |east london
# Processing Record 145 of set 1 |aklavik
# Processing Record 146 of set 1 |saravan
# Processing Record 147 of set 1 |provideniya
# Processing Record 148 of set 1 |airai
# Processing Record 149 of set 1 |saint george
# Skipping city...
# Processing Record 151 of set 1 |grindavik
# Processing Record 152 of set 1 |constitucion
# Processing Record 153 of set 1 |narsaq
# Processing Record 154 of set 1 |castro
# Processing Record 155 of set 1 |okhotsk
# Processing Record 156 of set 1 |necochea
# Processing Record 157 of set 1 |arraial do cabo
# Processing Record 158 of set 1 |ostrovnoy
# Processing Record 159 of set 1 |bontang
# Processing Record 160 of set 1 |lasa
# Skipping city...
# Processing Record 162 of set 1 |de aar
# Processing Record 163 of set 1 |fethiye
# Processing Record 164 of set 1 |oga
# Processing Record 165 of set 1 |merauke
# Processing Record 166 of set 1 |tiksi
# Processing Record 167 of set 1 |yulara
# Processing Record 168 of set 1 |aflao
# Processing Record 169 of set 1 |husavik
# Processing Record 170 of set 1 |cabo san lucas
# Processing Record 171 of set 1 |pangkalanbuun
# Processing Record 172 of set 1 |urucara
# Processing Record 173 of set 1 |laguna
# Processing Record 174 of set 1 |pemangkat
# Processing Record 175 of set 1 |victoria
# Processing Record 176 of set 1 |okato
# Processing Record 177 of set 1 |northam
# Processing Record 178 of set 1 |cocobeach
# Processing Record 179 of set 1 |ngunguru
# Processing Record 180 of set 1 |ancud
# Processing Record 181 of set 1 |vetluga
# Processing Record 182 of set 1 |damghan
# Processing Record 183 of set 1 |sisimiut
# Processing Record 184 of set 1 |astana
# Processing Record 185 of set 1 |calais
# Processing Record 186 of set 1 |qinggang
# Processing Record 187 of set 1 |tura
# Processing Record 188 of set 1 |san carlos de bariloche
# Processing Record 189 of set 1 |jacobabad
# Processing Record 190 of set 1 |gravdal
# Processing Record 191 of set 1 |mollendo
# Skipping city...
# Processing Record 193 of set 1 |ojinaga
# Processing Record 194 of set 1 |auki
# Processing Record 195 of set 1 |kumluca
# Processing Record 196 of set 1 |north platte
# Processing Record 197 of set 1 |tempio pausania
# Processing Record 198 of set 1 |hervey bay
# Processing Record 199 of set 1 |ribeira grande
# Processing Record 200 of set 1 |vila
# Processing Record 201 of set 1 |llanes
# Processing Record 202 of set 1 |mirnyy
# Skipping city...
# Processing Record 204 of set 1 |kaitangata
# Processing Record 205 of set 1 |monrovia
# Processing Record 206 of set 1 |warkworth
# Processing Record 207 of set 1 |macamic
# Processing Record 208 of set 1 |touros
# Processing Record 209 of set 1 |moratuwa
# Processing Record 210 of set 1 |portland
# Processing Record 211 of set 1 |souillac
# Skipping city...
# Processing Record 213 of set 1 |nurota
# Processing Record 214 of set 1 |vao
# Processing Record 215 of set 1 |saint-philippe
# Processing Record 216 of set 1 |nelson bay
# Processing Record 217 of set 1 |inta
# Processing Record 218 of set 1 |la rochelle
# Processing Record 219 of set 1 |winfield
# Processing Record 220 of set 1 |la romana
# Processing Record 221 of set 1 |diamantino
# Processing Record 222 of set 1 |diffa
# Processing Record 223 of set 1 |peniche
# Processing Record 224 of set 1 |maceio
# Processing Record 225 of set 1 |ishigaki
# Skipping city...
# Processing Record 227 of set 1 |ust-koksa
# Processing Record 228 of set 1 |tall kayf
# Processing Record 229 of set 1 |longyearbyen
# Processing Record 230 of set 1 |camopi
# Processing Record 231 of set 1 |nuevo progreso
# Processing Record 232 of set 1 |asyut
# Processing Record 233 of set 1 |tezu
# Skipping city...
# Processing Record 235 of set 1 |cairns
# Skipping city...
# Processing Record 237 of set 1 |nanaimo
# Processing Record 238 of set 1 |naze
# Processing Record 239 of set 1 |akyab
# Skipping city...
# Processing Record 241 of set 1 |kurya
# Processing Record 242 of set 1 |sokolo
# Processing Record 243 of set 1 |ocotepec
# Processing Record 244 of set 1 |davila
# Processing Record 245 of set 1 |beian
# Processing Record 246 of set 1 |pangnirtung
# Processing Record 247 of set 1 |abashiri
# Processing Record 248 of set 1 |srednekolymsk
# Processing Record 249 of set 1 |ambilobe
# Processing Record 250 of set 1 |palmer
# Skipping city...
# Processing Record 252 of set 1 |songjianghe
# Processing Record 253 of set 1 |kurilsk
# Processing Record 254 of set 1 |axim
# Processing Record 255 of set 1 |tautira
# Processing Record 256 of set 1 |richards bay
# Processing Record 257 of set 1 |gat
# Processing Record 258 of set 1 |kysyl-syr
# Processing Record 259 of set 1 |tatarskaya pishlya
# Processing Record 260 of set 1 |akkermanovka
# Processing Record 261 of set 1 |copiapo
# Skipping city...
# Processing Record 263 of set 1 |savannakhet
# Processing Record 264 of set 1 |sao filipe
# Processing Record 265 of set 1 |turukhansk
# Processing Record 266 of set 1 |sorong
# Processing Record 267 of set 1 |kushima
# Processing Record 268 of set 1 |sakaiminato
# Processing Record 269 of set 1 |north bend
# Processing Record 270 of set 1 |savalou
# Processing Record 271 of set 1 |lavrentiya
# Processing Record 272 of set 1 |torbay
# Processing Record 273 of set 1 |hatillo
# Processing Record 274 of set 1 |sept-iles
# Processing Record 275 of set 1 |ahipara
# Processing Record 276 of set 1 |kruisfontein
# Skipping city...
# Processing Record 278 of set 1 |chuy
# Skipping city...
# Skipping city...
# Processing Record 281 of set 1 |takoradi
# Processing Record 282 of set 1 |dingle
# Processing Record 283 of set 1 |almeirim
# Processing Record 284 of set 1 |malartic
# Processing Record 285 of set 1 |arlit
# Processing Record 286 of set 1 |abha
# Processing Record 287 of set 1 |mount gambier
# Processing Record 288 of set 1 |sungurlu
# Processing Record 289 of set 1 |pangody
# Processing Record 290 of set 1 |sitka
# Processing Record 291 of set 1 |mukhen
# Processing Record 292 of set 1 |saldanha
# Processing Record 293 of set 1 |echternach
# Processing Record 294 of set 1 |baie-saint-paul
# Processing Record 295 of set 1 |quepos
# Processing Record 296 of set 1 |kungurtug
# Processing Record 297 of set 1 |tafresh
# Processing Record 298 of set 1 |port lincoln
# Processing Record 299 of set 1 |coquimbo
# Skipping city...
# Processing Record 301 of set 1 |nanortalik
# Processing Record 302 of set 1 |rampura
# Skipping city...
# Skipping city...
# Processing Record 305 of set 1 |iqaluit
# Processing Record 306 of set 1 |auchi
# Processing Record 307 of set 1 |walvis bay
# Skipping city...
# Processing Record 309 of set 1 |norman wells
# Processing Record 310 of set 1 |lewiston
# Processing Record 311 of set 1 |labuhan
# Processing Record 312 of set 1 |lixourion
# Processing Record 313 of set 1 |storforshei
# Processing Record 314 of set 1 |prainha
# Processing Record 315 of set 1 |cap malheureux
# Processing Record 316 of set 1 |along
# Processing Record 317 of set 1 |tigil
# Skipping city...
# Processing Record 319 of set 1 |sola
# Skipping city...
# Processing Record 321 of set 1 |bathsheba
# Processing Record 322 of set 1 |mizan teferi
# Processing Record 323 of set 1 |klyuchi
# Processing Record 324 of set 1 |nadvoitsy
# Processing Record 325 of set 1 |coihaique
# Processing Record 326 of set 1 |tahta
# Processing Record 327 of set 1 |yemelyanovo
# Processing Record 328 of set 1 |vinh
# Processing Record 329 of set 1 |vanimo
# Processing Record 330 of set 1 |ambon
# Processing Record 331 of set 1 |muros
# Processing Record 332 of set 1 |keti bandar
# Processing Record 333 of set 1 |pekalongan
# Processing Record 334 of set 1 |vardo
# Processing Record 335 of set 1 |marondera
# Processing Record 336 of set 1 |codrington
# Processing Record 337 of set 1 |onega
# Processing Record 338 of set 1 |namatanai
# Processing Record 339 of set 1 |kpandu
# Processing Record 340 of set 1 |date
# Skipping city...
# Processing Record 342 of set 1 |bujumbura
# Processing Record 343 of set 1 |creston
# Processing Record 344 of set 1 |tateyama
# Processing Record 345 of set 1 |arman
# Skipping city...
# Processing Record 347 of set 1 |vila velha
# Processing Record 348 of set 1 |kashi
# Skipping city...
# Processing Record 350 of set 1 |amahai
# Processing Record 351 of set 1 |clacton-on-sea
# Processing Record 352 of set 1 |hambantota
# Processing Record 353 of set 1 |feicheng
# Processing Record 354 of set 1 |dandong
# Processing Record 355 of set 1 |borogontsy
# Processing Record 356 of set 1 |cabinda
# Processing Record 357 of set 1 |ola
# Processing Record 358 of set 1 |barreirinhas
# Processing Record 359 of set 1 |blagoyevo
# Processing Record 360 of set 1 |estrela
# Processing Record 361 of set 1 |goderich
# Processing Record 362 of set 1 |lagoa
# Processing Record 363 of set 1 |fairfield
# Processing Record 364 of set 1 |talnakh
# Processing Record 365 of set 1 |valparaiso
# Processing Record 366 of set 1 |itarema
# Processing Record 367 of set 1 |asau
# Processing Record 368 of set 1 |vostok
# Processing Record 369 of set 1 |leh
# Processing Record 370 of set 1 |haljala
# Processing Record 371 of set 1 |rajaldesar
# Processing Record 372 of set 1 |hithadhoo
# Processing Record 373 of set 1 |sturgeon falls
# Processing Record 374 of set 1 |pevek
# Processing Record 375 of set 1 |kidal
# Processing Record 376 of set 1 |katobu
# Processing Record 377 of set 1 |nyuksenitsa
# Processing Record 378 of set 1 |acari
# Processing Record 379 of set 1 |olafsvik
# Processing Record 380 of set 1 |smoky lake
# Processing Record 381 of set 1 |puerto madero
# Processing Record 382 of set 1 |brenham
# Processing Record 383 of set 1 |bonthe
# Processing Record 384 of set 1 |san quintin
# Processing Record 385 of set 1 |bumba
# Skipping city...
# Processing Record 387 of set 1 |san patricio
# Processing Record 388 of set 1 |saint-francois
# Processing Record 389 of set 1 |puerto escondido
# Processing Record 390 of set 1 |kulhudhuffushi
# Processing Record 391 of set 1 |celestun
# Processing Record 392 of set 1 |rapar
# Processing Record 393 of set 1 |yar-sale
# Processing Record 394 of set 1 |nhulunbuy
# Processing Record 395 of set 1 |iguape
# Processing Record 396 of set 1 |victor harbor
# Processing Record 397 of set 1 |nemuro
# Processing Record 398 of set 1 |siderno
# Processing Record 399 of set 1 |baghmara
# Processing Record 400 of set 1 |waipawa
# Processing Record 401 of set 1 |lorengau
# Processing Record 402 of set 1 |forio
# Processing Record 403 of set 1 |matiompong
# Processing Record 404 of set 1 |kanniyakumari
# Processing Record 405 of set 1 |alugan
# Processing Record 406 of set 1 |mahibadhoo
# Processing Record 407 of set 1 |havoysund
# Processing Record 408 of set 1 |channel-port aux basques
# Processing Record 409 of set 1 |tilichiki
# Skipping city...
# Processing Record 411 of set 1 |strezhevoy
# Processing Record 412 of set 1 |haines junction
# Processing Record 413 of set 1 |los llanos de aridane
# Processing Record 414 of set 1 |alvorada
# Processing Record 415 of set 1 |grand gaube
# Processing Record 416 of set 1 |mporokoso
# Processing Record 417 of set 1 |la asuncion
# Processing Record 418 of set 1 |ahar
# Processing Record 419 of set 1 |sembe
# Processing Record 420 of set 1 |vilyuysk
# Processing Record 421 of set 1 |usinsk
# Processing Record 422 of set 1 |komsomolskiy
# Processing Record 423 of set 1 |clyde river
# Processing Record 424 of set 1 |sinjar
# Skipping city...
# Processing Record 426 of set 1 |ayotzintepec
# Processing Record 427 of set 1 |luderitz
# Processing Record 428 of set 1 |presidencia roque saenz pena
# Processing Record 429 of set 1 |mandalgovi
# Processing Record 430 of set 1 |nizwa
# Processing Record 431 of set 1 |praia
# Processing Record 432 of set 1 |san juan
# Processing Record 433 of set 1 |gwadar
# Processing Record 434 of set 1 |goulburn
# Processing Record 435 of set 1 |banda aceh
# Processing Record 436 of set 1 |sur
# Processing Record 437 of set 1 |margate
# Processing Record 438 of set 1 |santa cruz cabralia
# Processing Record 439 of set 1 |redlands
# Processing Record 440 of set 1 |semey
# Processing Record 441 of set 1 |san cristobal
# Processing Record 442 of set 1 |gornyye klyuchi
# Processing Record 443 of set 1 |vestmannaeyjar
# Processing Record 444 of set 1 |chegdomyn
# Processing Record 445 of set 1 |toora-khem
# Processing Record 446 of set 1 |nome
# Processing Record 447 of set 1 |soller
# Processing Record 448 of set 1 |fort nelson
# Processing Record 449 of set 1 |magnitka
# Processing Record 450 of set 1 |seoul
# Processing Record 451 of set 1 |coahuayana
# Processing Record 452 of set 1 |kemijarvi
# Processing Record 453 of set 1 |sedalia
# Skipping city...
# Processing Record 455 of set 1 |ouadda
# Processing Record 456 of set 1 |elizabeth city
# Processing Record 457 of set 1 |ordu
# Processing Record 458 of set 1 |abu samrah
# Processing Record 459 of set 1 |bonga
# Processing Record 460 of set 1 |basco
# Processing Record 461 of set 1 |kambove
# Processing Record 462 of set 1 |umm bab
# Skipping city...
# Skipping city...
# Processing Record 465 of set 1 |beringovskiy
# Processing Record 466 of set 1 |pisco
# Processing Record 467 of set 1 |banjar
# Skipping city...
# Processing Record 469 of set 1 |birjand
# Processing Record 470 of set 1 |tacna
# Processing Record 471 of set 1 |khasan
# Processing Record 472 of set 1 |port hardy
# Processing Record 473 of set 1 |kurtamysh
# Processing Record 474 of set 1 |bridlington
# Processing Record 475 of set 1 |flin flon
# Processing Record 476 of set 1 |kahului
# Processing Record 477 of set 1 |roald
# Processing Record 478 of set 1 |luzern
# Skipping city...
# Processing Record 480 of set 1 |trairi
# Processing Record 481 of set 1 |saint-pierre
# Skipping city...
# Processing Record 483 of set 1 |mareeba
# Processing Record 484 of set 1 |hojai
# Processing Record 485 of set 1 |uribia
# Processing Record 486 of set 1 |severnoye
# Processing Record 487 of set 1 |evensk
# Processing Record 488 of set 1 |inhapi
# Processing Record 489 of set 1 |riyadh
# Processing Record 490 of set 1 |new ulm
# Processing Record 491 of set 1 |outlook
# Processing Record 492 of set 1 |nyurba
# Processing Record 493 of set 1 |killybegs
# Processing Record 494 of set 1 |jacksonville
# Processing Record 495 of set 1 |bay-khaak
# Skipping city...
# Processing Record 497 of set 1 |pacific grove
# Processing Record 498 of set 1 |tommot
# Processing Record 499 of set 1 |noyabrsk
# Processing Record 500 of set 1 |rajmahal
# Processing Record 501 of set 1 |gidole
# Processing Record 502 of set 1 |taltal
# Processing Record 503 of set 1 |oskemen
# Processing Record 504 of set 1 |nanning
# Processing Record 505 of set 1 |dong hoi
# Processing Record 506 of set 1 |teahupoo
# Processing Record 507 of set 1 |fagersta
# Processing Record 508 of set 1 |gizo
# Processing Record 509 of set 1 |rio gallegos
# Processing Record 510 of set 1 |ixtapa
# Processing Record 511 of set 1 |taoudenni
# Processing Record 512 of set 1 |san policarpo
# Processing Record 513 of set 1 |kununurra
# Processing Record 514 of set 1 |guangyuan
# Processing Record 515 of set 1 |kogon
# Processing Record 516 of set 1 |cockburn town
# Processing Record 517 of set 1 |henties bay
# Processing Record 518 of set 1 |madang
# Processing Record 519 of set 1 |magaria
# Processing Record 520 of set 1 |trenggalek
# Processing Record 521 of set 1 |mabaruma
# Processing Record 522 of set 1 |boali
# Processing Record 523 of set 1 |tari
# Processing Record 524 of set 1 |zhuhai
# Processing Record 525 of set 1 |acapulco
# Processing Record 526 of set 1 |dalby
# Processing Record 527 of set 1 |jiazi
# Processing Record 528 of set 1 |westport
# Processing Record 529 of set 1 |matay
# Processing Record 530 of set 1 |macapa
# Processing Record 531 of set 1 |ushtobe
# Processing Record 532 of set 1 |buala
# Processing Record 533 of set 1 |abu zabad
# Processing Record 534 of set 1 |vrangel
# Processing Record 535 of set 1 |pau dos ferros
# Processing Record 536 of set 1 |padang
# Processing Record 537 of set 1 |beloha
# Processing Record 538 of set 1 |yanagawa
# Processing Record 539 of set 1 |royal tunbridge wells
# Processing Record 540 of set 1 |san vicente
# Processing Record 541 of set 1 |whitehorse
# Processing Record 542 of set 1 |bonavista
# Processing Record 543 of set 1 |tombouctou
# Processing Record 544 of set 1 |mansa
# Processing Record 545 of set 1 |lakes entrance
# Processing Record 546 of set 1 |pimentel
# Processing Record 547 of set 1 |havre
# Processing Record 548 of set 1 |penalva
# Processing Record 549 of set 1 |balkanabat
# Processing Record 550 of set 1 |tucuman
# Processing Record 551 of set 1 |popondetta
# Processing Record 552 of set 1 |cortez
# Processing Record 553 of set 1 |ossora
# Processing Record 554 of set 1 |uaua
# Processing Record 555 of set 1 |glenwood springs
# Processing Record 556 of set 1 |inhambane
# Processing Record 557 of set 1 |yumen
# Processing Record 558 of set 1 |hobyo
# Processing Record 559 of set 1 |hofn
# Processing Record 560 of set 1 |oranjemund
# Processing Record 561 of set 1 |carlsbad
# Processing Record 562 of set 1 |grammichele
# Processing Record 563 of set 1 |brooks
# Processing Record 564 of set 1 |fairlie
# Processing Record 565 of set 1 |betare oya
# Processing Record 566 of set 1 |srikakulam
# Processing Record 567 of set 1 |tiarei
# Processing Record 568 of set 1 |san jose
# Processing Record 569 of set 1 |juchen
# Processing Record 570 of set 1 |dudinka
# Processing Record 571 of set 1 |kaihua
# Processing Record 572 of set 1 |newton
# Processing Record 573 of set 1 |mazagao
# Processing Record 574 of set 1 |kosh-agach
# Processing Record 575 of set 1 |soubre
# Processing Record 576 of set 1 |meulaboh
# Processing Record 577 of set 1 |charagua
# Processing Record 578 of set 1 |kasongo-lunda
# Processing Record 579 of set 1 |ascension
# Processing Record 580 of set 1 |korla
# Processing Record 581 of set 1 |wasco
# Processing Record 582 of set 1 |kedougou
# Processing Record 583 of set 1 |bubaque
# Processing Record 584 of set 1 |ponta delgada
# Processing Record 585 of set 1 |kirksville
# Processing Record 586 of set 1 |nouakchott
# Processing Record 587 of set 1 |houma
# Skipping city...
# Processing Record 589 of set 1 |san andres
# Processing Record 590 of set 1 |polunochnoye
# Processing Record 591 of set 1 |san matias
# Processing Record 592 of set 1 |deputatskiy
# Processing Record 593 of set 1 |plettenberg bay
# Processing Record 594 of set 1 |kahama

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | darhan
# Processing Record 3 of Set 1 | tarakan
# Processing Record 4 of Set 1 | komsomolskiy
# Processing Record 5 of Set 1 | souillac
# Processing Record 6 of Set 1 | jiuquan
# Processing Record 7 of Set 1 | sesheke
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | clarence town
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | magadan
# Processing Record 12 of Set 1 | salym
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | arys
# Processing Record 16 of Set 1 | prince rupert
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | rio gallegos
# Processing Record 22 of Set 1 | kropotkin
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | dahra
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | stephenville
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | north bend
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | faya
# Processing Record 31 of Set 1 | vryburg
# Processing Record 32 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | zhigansk
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | thompson
# Processing Record 37 of Set 1 | margate
# Processing Record 38 of Set 1 | oksfjord
# Processing Record 39 of Set 1 | chumikan
# Processing Record 40 of Set 1 | kudat
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | laguna
# Processing Record 43 of Set 1 | abu zabad
# Processing Record 44 of Set 1 | jiroft
# City not found. Skipping...
# Processing Record 45 of Set 1 | saint-joseph
# Processing Record 46 of Set 1 | cabo san lucas
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | kirkwall
# Processing Record 50 of Set 1 | luderitz
# Processing Record 0 of Set 2 | bethel
# Processing Record 1 of Set 2 | vao
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | melo
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | college
# Processing Record 6 of Set 2 | prinos
# Processing Record 7 of Set 2 | kodiak
# Processing Record 8 of Set 2 | cabo rojo
# Processing Record 9 of Set 2 | nuevo ideal
# Processing Record 10 of Set 2 | yumen
# Processing Record 11 of Set 2 | khonsa
# Processing Record 12 of Set 2 | biloela
# Processing Record 13 of Set 2 | sungaipenuh
# Processing Record 14 of Set 2 | namatanai
# Processing Record 15 of Set 2 | kungurtug
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | san rafael
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | hovd
# Processing Record 21 of Set 2 | isangel
# Processing Record 22 of Set 2 | ancud
# Processing Record 23 of Set 2 | humenne
# Processing Record 24 of Set 2 | natal
# Processing Record 25 of Set 2 | moron
# Processing Record 26 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 2 | kaitangata
# Processing Record 28 of Set 2 | poya
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | pangai
# Processing Record 31 of Set 2 | havre-saint-pierre
# Processing Record 32 of Set 2 | takoradi
# Processing Record 33 of Set 2 | bathsheba
# Processing Record 34 of Set 2 | kirksville
# Processing Record 35 of Set 2 | pangody
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | borujan
# City not found. Skipping...
# Processing Record 39 of Set 2 | cambridge
# Processing Record 40 of Set 2 | damaturu
# Processing Record 41 of Set 2 | bardiyah
# City not found. Skipping...
# Processing Record 42 of Set 2 | carbonear
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | mar del plata
# Processing Record 45 of Set 2 | charlestown
# Processing Record 46 of Set 2 | mixtepec
# City not found. Skipping...
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | boissevain
# Processing Record 49 of Set 2 | bluff
# Processing Record 0 of Set 3 | kudahuvadhoo
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | tairua
# Processing Record 3 of Set 3 | tuatapere
# Processing Record 4 of Set 3 | bredasdorp
# Processing Record 5 of Set 3 | silver city
# Processing Record 6 of Set 3 | veracruz
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | rincon
# Processing Record 9 of Set 3 | hermanus
# Processing Record 10 of Set 3 | toktogul
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | yilan
# Processing Record 14 of Set 3 | mumford
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | diffa
# Processing Record 17 of Set 3 | saskylakh
# Processing Record 18 of Set 3 | yambio
# City not found. Skipping...
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | ribeira grande
# Processing Record 21 of Set 3 | dana point
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | upernavik
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | barabinsk
# Processing Record 26 of Set 3 | port lincoln
# Processing Record 27 of Set 3 | malinovoye ozero
# Processing Record 28 of Set 3 | ambatofinandrahana
# Processing Record 29 of Set 3 | puerto del rosario
# Processing Record 30 of Set 3 | pevek
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | zhezkazgan
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | batagay-alyta
# Processing Record 35 of Set 3 | baltiysk
# Processing Record 36 of Set 3 | parfino
# Processing Record 37 of Set 3 | barrow
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | mackenzie
# Processing Record 40 of Set 3 | lebanon
# Processing Record 41 of Set 3 | nishihara
# Processing Record 42 of Set 3 | antalaha
# Processing Record 43 of Set 3 | narsaq
# Processing Record 44 of Set 3 | hami
# Processing Record 45 of Set 3 | shaoyang
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 3 | leningradskiy
# Processing Record 49 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 0 of Set 4 | mehamn
# Processing Record 1 of Set 4 | vaini
# Processing Record 2 of Set 4 | bara
# Processing Record 3 of Set 4 | krasnoselkup
# City not found. Skipping...
# Processing Record 4 of Set 4 | risch
# Processing Record 5 of Set 4 | along
# Processing Record 6 of Set 4 | vestmanna
# Processing Record 7 of Set 4 | mwinilunga
# Processing Record 8 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 4 | pozo colorado
# Processing Record 10 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | werder
# Processing Record 12 of Set 4 | lovington
# Processing Record 13 of Set 4 | qasigiannguit
# Processing Record 14 of Set 4 | mackay
# Processing Record 15 of Set 4 | pisco
# Processing Record 16 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 4 | sisimiut
# Processing Record 18 of Set 4 | banda aceh
# Processing Record 19 of Set 4 | fortuna
# Processing Record 20 of Set 4 | ouadda
# Processing Record 21 of Set 4 | sucua
# Processing Record 22 of Set 4 | nanortalik
# Processing Record 23 of Set 4 | longyearbyen
# Processing Record 24 of Set 4 | araouane
# Processing Record 25 of Set 4 | barra patuca
# Processing Record 26 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 4 | wattegama
# Processing Record 29 of Set 4 | tuktoyaktuk
# Processing Record 30 of Set 4 | tabou
# Processing Record 31 of Set 4 | arraial do cabo
# Processing Record 32 of Set 4 | stabat
# Processing Record 33 of Set 4 | klaksvik
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | sumbawanga
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | bambous virieux
# Processing Record 39 of Set 4 | saint george
# Processing Record 40 of Set 4 | hibbing
# Processing Record 41 of Set 4 | bandar-e lengeh
# Processing Record 42 of Set 4 | viedma
# Processing Record 43 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 4 | port keats
# Processing Record 46 of Set 4 | jinchang
# Processing Record 47 of Set 4 | lata
# Processing Record 48 of Set 4 | fairbanks
# Processing Record 49 of Set 4 | olupona
# Processing Record 0 of Set 5 | genhe
# Processing Record 1 of Set 5 | dingle
# Processing Record 2 of Set 5 | williamsburg
# Processing Record 3 of Set 5 | anloga
# Processing Record 4 of Set 5 | esperance
# Processing Record 5 of Set 5 | saint-philippe
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 9 of Set 5 | dalvik
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | inta
# Processing Record 12 of Set 5 | naze
# Processing Record 13 of Set 5 | juneau
# Processing Record 14 of Set 5 | kurumkan
# Processing Record 15 of Set 5 | ranong
# Processing Record 16 of Set 5 | cockburn town
# Processing Record 17 of Set 5 | sakakah
# City not found. Skipping...
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | hoquiam
# Processing Record 20 of Set 5 | georgetown
# Processing Record 21 of Set 5 | marv dasht
# City not found. Skipping...
# Processing Record 22 of Set 5 | ostrovnoy
# Processing Record 23 of Set 5 | placido de castro
# Processing Record 24 of Set 5 | anar darreh
# City not found. Skipping...
# Processing Record 25 of Set 5 | suksun
# Processing Record 26 of Set 5 | bengkulu
# City not found. Skipping...
# Processing Record 27 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 5 | faanui
# Processing Record 30 of Set 5 | ust-barguzin
# Processing Record 31 of Set 5 | itacare
# Processing Record 32 of Set 5 | nacogdoches
# Processing Record 33 of Set 5 | cape canaveral
# Processing Record 34 of Set 5 | puri
# Processing Record 35 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 5 | jubayl
# City not found. Skipping...
# Processing Record 37 of Set 5 | tarnow
# Processing Record 38 of Set 5 | vicuna
# City not found. Skipping...
# Processing Record 39 of Set 5 | jumla
# Processing Record 40 of Set 5 | ust-kuyga
# Processing Record 41 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 5 | rocha
# Processing Record 43 of Set 5 | tasiilaq
# Processing Record 44 of Set 5 | ribeira brava
# Processing Record 45 of Set 5 | norrtalje
# Processing Record 46 of Set 5 | warrington
# Processing Record 47 of Set 5 | noumea
# Processing Record 48 of Set 5 | akyab
# City not found. Skipping...
# Processing Record 49 of Set 5 | meadow lake
# Processing Record 0 of Set 6 | chimoio
# Processing Record 1 of Set 6 | oussouye
# Processing Record 2 of Set 6 | gazojak
# Processing Record 3 of Set 6 | balikpapan
# Processing Record 4 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 5 of Set 6 | torbay
# Processing Record 6 of Set 6 | elko
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | saquena
# Processing Record 9 of Set 6 | makokou
# Processing Record 10 of Set 6 | hambantota
# Processing Record 11 of Set 6 | beidao
# Processing Record 12 of Set 6 | praia da vitoria
# Processing Record 13 of Set 6 | port blair
# Processing Record 14 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 6 | awbari
# Processing Record 16 of Set 6 | reconquista
# Processing Record 17 of Set 6 | aklavik
# Processing Record 18 of Set 6 | teya
# Processing Record 19 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 6 | edinet
# Processing Record 21 of Set 6 | taoudenni
# Processing Record 22 of Set 6 | goundam
# Processing Record 23 of Set 6 | socorro
# Processing Record 24 of Set 6 | merrill
# Processing Record 25 of Set 6 | vagay
# Processing Record 26 of Set 6 | comodoro rivadavia
# Processing Record 27 of Set 6 | pudozh
# Processing Record 28 of Set 6 | sambava
# Processing Record 29 of Set 6 | batesville
# Processing Record 30 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 6 | itaituba
# Processing Record 32 of Set 6 | la asuncion
# Processing Record 33 of Set 6 | east london
# Processing Record 34 of Set 6 | chipinge
# Processing Record 35 of Set 6 | cedartown
# Processing Record 36 of Set 6 | miranda
# Processing Record 37 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 6 | sabang
# Processing Record 39 of Set 6 | abong mbang
# Processing Record 40 of Set 6 | port hardy
# Processing Record 41 of Set 6 | canon city
# Processing Record 42 of Set 6 | santa quiteria do maranhao
# Processing Record 43 of Set 6 | ryotsu
# Processing Record 44 of Set 6 | pacific grove
# Processing Record 45 of Set 6 | kishi
# Processing Record 46 of Set 6 | obihiro
# Processing Record 47 of Set 6 | katsuura
# Processing Record 48 of Set 6 | saint augustine
# Processing Record 49 of Set 6 | bushehr
# Processing Record 0 of Set 7 | nizhniy kuranakh
# Processing Record 1 of Set 7 | bonthe
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | nizwa
# Processing Record 4 of Set 7 | kamenka
# Processing Record 5 of Set 7 | tiksi
# Processing Record 6 of Set 7 | saint anthony
# Processing Record 7 of Set 7 | vardo
# Processing Record 8 of Set 7 | riyadh
# Processing Record 9 of Set 7 | malim
# Processing Record 10 of Set 7 | makakilo city
# Processing Record 11 of Set 7 | henties bay
# Processing Record 12 of Set 7 | caravelas
# Processing Record 13 of Set 7 | gazli
# Processing Record 14 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 7 | san juan
# Processing Record 16 of Set 7 | moose factory
# Processing Record 17 of Set 7 | kashi
# City not found. Skipping...
# Processing Record 18 of Set 7 | fuerte olimpo
# Processing Record 19 of Set 7 | saint-pierre
# Processing Record 20 of Set 7 | raca
# Processing Record 21 of Set 7 | san quintin
# Processing Record 22 of Set 7 | sedro-woolley
# Processing Record 23 of Set 7 | berdigestyakh
# Processing Record 24 of Set 7 | high level
# Processing Record 25 of Set 7 | khorramshahr
# Processing Record 26 of Set 7 | san jose
# Processing Record 27 of Set 7 | emba
# Processing Record 28 of Set 7 | farcasu
# Processing Record 29 of Set 7 | kruisfontein
# Processing Record 30 of Set 7 | garango
# Processing Record 31 of Set 7 | boa vista
# Processing Record 32 of Set 7 | novopskov
# Processing Record 33 of Set 7 | shimoda
# Processing Record 34 of Set 7 | portland
# Processing Record 35 of Set 7 | waingapu
# Processing Record 36 of Set 7 | zuwarah
# Processing Record 37 of Set 7 | muroto
# Processing Record 38 of Set 7 | sao filipe
# Processing Record 39 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 7 | lunenburg
# Processing Record 41 of Set 7 | novyy urengoy
# Processing Record 42 of Set 7 | ferry pass
# Processing Record 43 of Set 7 | crotone
# Processing Record 44 of Set 7 | arlit
# Processing Record 45 of Set 7 | auki
# Processing Record 46 of Set 7 | ambilobe
# Processing Record 47 of Set 7 | ilhabela
# Processing Record 48 of Set 7 | kirakira
# Processing Record 49 of Set 7 | cidreira
# Processing Record 0 of Set 8 | chambas
# Processing Record 1 of Set 8 | gat
# Processing Record 2 of Set 8 | petatlan
# Processing Record 3 of Set 8 | nha trang
# Processing Record 4 of Set 8 | hermosillo
# Processing Record 5 of Set 8 | airai
# Processing Record 6 of Set 8 | kahului
# Processing Record 7 of Set 8 | yeppoon
# Processing Record 8 of Set 8 | manavgat
# Processing Record 9 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 10 of Set 8 | xambioa
# City not found. Skipping...
# Processing Record 11 of Set 8 | katima mulilo
# Processing Record 12 of Set 8 | carutapera
# Processing Record 13 of Set 8 | yar-sale
# Processing Record 14 of Set 8 | haines junction
# Processing Record 15 of Set 8 | half moon bay
# Processing Record 16 of Set 8 | vanavara
# Processing Record 17 of Set 8 | santander
# Processing Record 18 of Set 8 | amuntai
# Processing Record 19 of Set 8 | esmeraldas
# Processing Record 20 of Set 8 | okhotsk
# Processing Record 21 of Set 8 | datong
# Processing Record 22 of Set 8 | sidi ali
# Processing Record 23 of Set 8 | muravlenko
# Processing Record 24 of Set 8 | amahai
# Processing Record 25 of Set 8 | santa isabel do rio negro
# Processing Record 26 of Set 8 | wageningen
# Processing Record 27 of Set 8 | svetlogorsk
# Processing Record 28 of Set 8 | paita
# Processing Record 29 of Set 8 | maniitsoq
# Processing Record 30 of Set 8 | port augusta
# Processing Record 31 of Set 8 | yulara
# Processing Record 32 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 8 | hofn
# Processing Record 34 of Set 8 | pulupandan
# Processing Record 35 of Set 8 | wajima
# Processing Record 36 of Set 8 | dnestrovsc
# Processing Record 37 of Set 8 | biak
# Processing Record 38 of Set 8 | bam
# Processing Record 39 of Set 8 | tacoronte
# Processing Record 40 of Set 8 | otavi
# Processing Record 41 of Set 8 | adrar
# Processing Record 42 of Set 8 | srednekolymsk
# Processing Record 43 of Set 8 | belmonte
# Processing Record 44 of Set 8 | san cristobal
# Processing Record 45 of Set 8 | kalomo
# City not found. Skipping...
# Processing Record 46 of Set 8 | callaway
# Processing Record 47 of Set 8 | birao
# Processing Record 48 of Set 8 | itoman
# Processing Record 49 of Set 8 | uch
# Processing Record 0 of Set 9 | santona
# Processing Record 1 of Set 9 | onguday
# Processing Record 2 of Set 9 | hangu
# Processing Record 3 of Set 9 | geraldton
# Processing Record 4 of Set 9 | gorele
# Processing Record 5 of Set 9 | erenhot
# Processing Record 6 of Set 9 | hauterive
# Processing Record 7 of Set 9 | kerema
# Processing Record 8 of Set 9 | jalu
# Processing Record 9 of Set 9 | inhambane
# Processing Record 10 of Set 9 | kenai
# Processing Record 11 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 12 of Set 9 | joshimath
# Processing Record 13 of Set 9 | hamilton
# Processing Record 14 of Set 9 | talnakh
# Processing Record 15 of Set 9 | nam tha
# City not found. Skipping...
# Processing Record 16 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 9 | egvekinot
# Processing Record 18 of Set 9 | victoria
# Processing Record 19 of Set 9 | atbasar
# Processing Record 20 of Set 9 | bulembu
# Processing Record 21 of Set 9 | hohhot
# Processing Record 22 of Set 9 | halifax
# Processing Record 23 of Set 9 | rehoboth
# Processing Record 24 of Set 9 | beloha
# Processing Record 25 of Set 9 | sehithwa
# Processing Record 26 of Set 9 | burdur
# Processing Record 27 of Set 9 | baruun-urt
# Processing Record 28 of Set 9 | fagernes
# Processing Record 29 of Set 9 | domoni
# City not found. Skipping...
# Processing Record 30 of Set 9 | toyooka
# Processing Record 31 of Set 9 | nantucket
# Processing Record 32 of Set 9 | martaban
# Processing Record 33 of Set 9 | puerto escondido
# Processing Record 34 of Set 9 | port moresby
# Processing Record 35 of Set 9 | malinovskiy
# Processing Record 36 of Set 9 | kumluca
# Processing Record 37 of Set 9 | salinas
# Processing Record 38 of Set 9 | mount isa
# Processing Record 39 of Set 9 | cherskiy
# Processing Record 40 of Set 9 | gobabis
# Processing Record 41 of Set 9 | bilma
# Processing Record 42 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 43 of Set 9 | fort nelson
# Processing Record 44 of Set 9 | quesnel
# Processing Record 45 of Set 9 | dakar
# Processing Record 46 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 47 of Set 9 | santiago del estero
# Processing Record 48 of Set 9 | buala
# Processing Record 49 of Set 9 | irbeyskoye
# Processing Record 0 of Set 10 | vila franca do campo
# Processing Record 1 of Set 10 | coihaique
# Processing Record 2 of Set 10 | los llanos de aridane
# Processing Record 3 of Set 10 | muros
# Processing Record 4 of Set 10 | port hedland
# Processing Record 5 of Set 10 | kieta
# Processing Record 6 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 10 | green river
# Processing Record 8 of Set 10 | mosonmagyarovar
# Processing Record 9 of Set 10 | mindelo
# Processing Record 10 of Set 10 | roblin
# Processing Record 11 of Set 10 | la ronge
# Processing Record 12 of Set 10 | tubuala
# Processing Record 13 of Set 10 | port-gentil
# Processing Record 14 of Set 10 | mordovo
# Processing Record 15 of Set 10 | clyde river
# Processing Record 16 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 10 | aykhal
# Processing Record 18 of Set 10 | tuensang
# Processing Record 19 of Set 10 | pascagoula
# Processing Record 20 of Set 10 | korla
# City not found. Skipping...
# Processing Record 21 of Set 10 | canto do buriti
# Processing Record 22 of Set 10 | bijie
# Processing Record 23 of Set 10 | san-pedro
# Processing Record 24 of Set 10 | luorong
# Processing Record 25 of Set 10 | yei
# City not found. Skipping...
# Processing Record 26 of Set 10 | berlevag
# Processing Record 27 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 10 | satipo
# Processing Record 29 of Set 10 | rawson
# Processing Record 30 of Set 10 | marsh harbour
# Processing Record 31 of Set 10 | taupo
# Processing Record 32 of Set 10 | san carlos de bariloche
# Processing Record 33 of Set 10 | pervomayskoye
# Processing Record 34 of Set 10 | chicama
# Processing Record 35 of Set 10 | angoche
# Processing Record 36 of Set 10 | brae
# Processing Record 37 of Set 10 | manokwari
# Processing Record 38 of Set 10 | mauganj
# Processing Record 39 of Set 10 | te anau
# Processing Record 40 of Set 10 | vila velha
# Processing Record 41 of Set 10 | tautira
# Processing Record 42 of Set 10 | dong xoai
# Processing Record 43 of Set 10 | batemans bay
# Processing Record 44 of Set 10 | diapaga
# Processing Record 45 of Set 10 | mangrol
# Processing Record 46 of Set 10 | mersing
# Processing Record 47 of Set 10 | maldonado
# Processing Record 48 of Set 10 | mikhaylovka
# Processing Record 49 of Set 10 | temple
# Processing Record 0 of Set 11 | gigmoto
# Processing Record 1 of Set 11 | makow mazowiecki
# Processing Record 2 of Set 11 | lasa
# Processing Record 3 of Set 11 | mazamari
# Processing Record 4 of Set 11 | matagami
# Processing Record 5 of Set 11 | steamboat springs
# Processing Record 6 of Set 11 | mount gambier
# Processing Record 7 of Set 11 | chyhyryn
# Processing Record 8 of Set 11 | nortelandia
# Processing Record 9 of Set 11 | imperial
# Processing Record 10 of Set 11 | progreso
# Processing Record 11 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 12 of Set 11 | arriaga
# Processing Record 13 of Set 11 | qusar
# Processing Record 14 of Set 11 | tessalit
# Processing Record 15 of Set 11 | de aar
# Processing Record 16 of Set 11 | kutum
# Processing Record 17 of Set 11 | ketchikan
# Processing Record 18 of Set 11 | peleduy
# Processing Record 19 of Set 11 | libenge
# Processing Record 20 of Set 11 | kapoeta
# City not found. Skipping...
# Processing Record 21 of Set 11 | tomatlan
# Processing Record 22 of Set 11 | lalmohan
# Processing Record 23 of Set 11 | vastervik
# City not found. Skipping...
# Processing Record 24 of Set 11 | serowe
# Processing Record 25 of Set 11 | mihail kogalniceanu
# Processing Record 26 of Set 11 | broken hill
# Processing Record 27 of Set 11 | ajaccio
# Processing Record 28 of Set 11 | suntar
# Processing Record 29 of Set 11 | mezica
# Processing Record 30 of Set 11 | sitka
# Processing Record 31 of Set 11 | ewa beach
# Processing Record 32 of Set 11 | songea
# Processing Record 33 of Set 11 | monroe
# Processing Record 34 of Set 11 | cravo norte
# Processing Record 35 of Set 11 | ystad
# Processing Record 36 of Set 11 | beyneu
# Processing Record 37 of Set 11 | almaznyy
# Processing Record 38 of Set 11 | vestmannaeyjar
# Processing Record 39 of Set 11 | cananeia
# Processing Record 40 of Set 11 | alta floresta
# Processing Record 41 of Set 11 | maketu
# Processing Record 42 of Set 11 | mecca
# Processing Record 43 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 44 of Set 11 | manta
# Processing Record 45 of Set 11 | nebug
# Processing Record 46 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 11 | constitucion
# Processing Record 48 of Set 11 | cabimas
# Processing Record 49 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 0 of Set 12 | khudumelapye
# Processing Record 1 of Set 12 | husavik
# Processing Record 2 of Set 12 | olinda
# Processing Record 3 of Set 12 | coquimbo
# Processing Record 4 of Set 12 | kambove
# Processing Record 5 of Set 12 | iquique
# Processing Record 6 of Set 12 | yenagoa
# Processing Record 7 of Set 12 | konakovo
# Processing Record 8 of Set 12 | labuhan
# Processing Record 9 of Set 12 | sampit
# Processing Record 10 of Set 12 | gayny
# Processing Record 11 of Set 12 | trafaria
# Processing Record 12 of Set 12 | zyryanka
# Processing Record 13 of Set 12 | soavinandriana
# Processing Record 14 of Set 12 | xiongzhou
# Processing Record 15 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 12 | batamshinskiy
# Processing Record 18 of Set 12 | kailua
# Processing Record 19 of Set 12 | kaliyaganj
# Processing Record 20 of Set 12 | cozumel
# City not found. Skipping...
# Processing Record 21 of Set 12 | obo
# Processing Record 22 of Set 12 | mushie
# Processing Record 23 of Set 12 | ishigaki
# Processing Record 24 of Set 12 | newport
# Processing Record 25 of Set 12 | quang ngai
# Processing Record 26 of Set 12 | butembo
# Processing Record 27 of Set 12 | palmer
# Processing Record 28 of Set 12 | motril
# Processing Record 29 of Set 12 | patitirion
# Processing Record 30 of Set 12 | omboue
# Processing Record 31 of Set 12 | waipawa
# Processing Record 32 of Set 12 | sakaiminato
# Processing Record 33 of Set 12 | raga
# City not found. Skipping...
# Processing Record 34 of Set 12 | xingcheng
# Processing Record 35 of Set 12 | necochea
# Processing Record 36 of Set 12 | gao
# Processing Record 37 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 39 of Set 12 | jiwani
# Processing Record 40 of Set 12 | yurla
# Processing Record 41 of Set 12 | codrington
# Processing Record 42 of Set 12 | kalmunai
# Processing Record 43 of Set 12 | flinders
# Processing Record 44 of Set 12 | primorsko-akhtarsk
# Processing Record 45 of Set 12 | ilulissat
# Processing Record 46 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 12 | isfana
# Processing Record 48 of Set 12 | borshchiv
# Processing Record 49 of Set 12 | hobyo
# Processing Record 0 of Set 13 | aktash
# City not found. Skipping...
# Processing Record 1 of Set 13 | syamzha
# Processing Record 2 of Set 13 | mahibadhoo
# Processing Record 3 of Set 13 | tiznit
# Processing Record 4 of Set 13 | point fortin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Check length of all the arrays
print(len(temp), len(cld), len(country),len(date),len(hum),len(lat),len(lng),len(mtemp),len(wspeed))
# Out:
# 546 546 546 546 546 546 546 546 546

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "city": cities,
    "temp": temp,
    "cloudiness": cld,
    "country": country,
    "date": date,
    "humidity": hum,
    "lat": lat,
    "lng": lng,
    "max temp": mtemp,
    "wind speed":wspeed}

# Save Data to csv
city_weather_df.to_csv("cities.csv")

#Display the dataframe first 100 values
city_weather_df = pd.DataFrame({ key:pd.Series(value) for key, value in weather_dict.items() })
city_weather_df.head(100)
# Out:
#               city   temp  cloudiness country          date  humidity    lat  \
# 0        jamestown  44.83        75.0      US  1.586232e+09      26.0  42.10
# 1           dikson  -2.18        52.0      RU  1.586233e+09      92.0  73.51
# 2      bandarbeyla  78.80         0.0      SO  1.586233e+09      67.0   9.49
# 3            pital  70.14        91.0      CO  1.586233e+09      59.0   2.27
# 4   port elizabeth  57.20        60.0      ZA  1.586233e+09      47.0 -33.92
# ..             ...    ...         ...     ...           ...       ...    ...
# 95           totma  37.40         7.0      RU  1.586233e+09      32.0  66.00
# 96          kodiak  42.64        24.0      GB  1.586233e+09      93.0  50.15
# 97       mendahara  87.80        75.0      PW  1.586233e+09      66.0   7.04
# 98        tessalit  49.28        90.0      US  1.586233e+09      93.0  40.60
# 99         timmins  83.26        97.0      KI  1.586233e+09      69.0   3.07
#
#        lng  max temp  wind speed
# 0   -79.24     48.00        1.34
# 1    80.55     -2.18        9.55
# 2    50.81     78.80        5.21
# 3   -75.80     70.14        1.45
# 4    25.57     57.20       23.04
# ..     ...       ...         ...
# 95  111.50     37.40        6.71
# 96   -5.07     46.00       11.41
# 97  134.26     87.80       10.29
# 98 -124.16     51.01        8.97
# 99  172.79     83.26        3.33
#
# [100 rows x 10 columns]

# %%
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  severo-kurilsk          92      RU  1534988024        93  50.68  156.12
# 1          darhan           8      MN  1534988024        71  49.49  105.92
# 2         tarakan          48      ID  1534988024       100   3.30  117.63
# 3    komsomolskiy          48      RU  1534987754        72  67.55   63.78
# 4        souillac           0      FR  1534986000        73  45.60   -0.60
#
#    Max Temp  Wind Speed
# 0     54.27        2.73
# 1     72.81        8.55
# 2     80.10        4.41
# 3     54.46       15.46
# 4     71.60        3.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
#Your first requirement is to create a series of scatter plots to showcase the following relationships:

#Temperature (F) vs. Latitude
#Humidity (%) vs. Latitude
#Cloudiness (%) vs. Latitude
#Wind Speed (mph) vs. Latitude

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_weather_df["lat"], city_weather_df["temp"], marker="o",edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature")
plt.ylabel("Temperature (Farenheit)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInCities.png")

# Show plot
plt.show()

# %%
#The scatter plot shows that those cities that are closer to the equator have warmer temperatures.  l0#The temperature is colder for those cities north of the equator.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type

plt.scatter(city_weather_df["lat"], city_weather_df["humidity"], marker="o",edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type

plt.scatter(city_weather_df["lat"], city_weather_df["cloudiness"], marker="o",edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type

plt.scatter(city_weather_df["lat"], city_weather_df["wind speed"], marker="o",edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeedInCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern Hemisphere DataFrames
northern_hemisphere = city_weather_df.loc[city_weather_df['lat']>=0,:]
northern_hemisphere.head()
# Out:
#    Unnamed: 0         city   temp  cloudiness country          date  humidity  \
# 0           0    jamestown  44.83        75.0      US  1.586232e+09      26.0
# 1           1       dikson  -2.18        52.0      RU  1.586233e+09      92.0
# 2           2  bandarbeyla  78.80         0.0      SO  1.586233e+09      67.0
# 3           3        pital  70.14        91.0      CO  1.586233e+09      59.0
# 8           8        asosa  73.78        56.0      ET  1.586233e+09      28.0
#
#      lat    lng  max temp  wind speed
# 0  42.10 -79.24     48.00        1.34
# 1  73.51  80.55     -2.18        9.55
# 2   9.49  50.81     78.80        5.21
# 3   2.27 -75.80     70.14        1.45
# 8  10.07  34.53     73.78        3.09

# %%
# Create Southern Hemisphere DataFrames
southern_hemisphere = city_weather_df.loc[city_weather_df['lat']<=0,:]
southern_hemisphere.head()
# Out:
#    Unnamed: 0            city   temp  cloudiness country          date  \
# 4           4  port elizabeth  57.20        60.0      ZA  1.586233e+09
# 5           5       geraldton  84.20        59.0      AU  1.586233e+09
# 6           6       busselton  83.93        32.0      AU  1.586233e+09
# 7           7         mataura  54.00        41.0      NZ  1.586233e+09
# 9           9        waingapu  87.19       100.0      ID  1.586233e+09
#
#    humidity    lat     lng  max temp  wind speed
# 4      47.0 -33.92   25.57     57.20       23.04
# 5      45.0 -28.77  114.60     84.20        8.05
# 6      22.0 -33.65  115.33     84.99       11.32
# 7      75.0 -46.19  168.86     54.00       21.00
# 9      62.0  -9.66  120.26     87.19        4.27

# %%
#Northern Hemisphere - Temperature (F) vs. Latitude
#Southern Hemisphere - Temperature (F) vs. Latitude
#Northern Hemisphere - Humidity (%) vs. Latitude
#Southern Hemisphere - Humidity (%) vs. Latitude
#Northern Hemisphere - Cloudiness (%) vs. Latitude
#Southern Hemisphere - Cloudiness (%) vs. Latitude
#Northern Hemisphere - Wind Speed (mph) vs. Latitude
#Southern Hemisphere - Wind Speed (mph) vs. Latitude

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Build a scatter plot for each data type
plt.scatter(northern_hemisphere["lat"], northern_hemisphere["max temp"], marker="o")

# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemisphere["lat"], northern_hemisphere["max temp"])

# Get regression values
regress_values = northern_hemisphere["lat"] * slope + intercept
 
plt.plot(northern_hemisphere["lat"],regress_values,"r-")    

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
                                                                                                   

# Incorporate the other graph properties
plt.title("Northern City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (Farenheit)")
plt.xlabel("Latitude")
#plt.grid(True)
plt.annotate(line_eq,(20,15),fontsize=15,color="red")  


# Print r square value
print(f"The r-squared is: {rvalue**2}")


# Save the figure
plt.savefig("TemperatureInNorthernCities.png")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.8212201408569691

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Build a scatter plot for each data type
plt.scatter(southern_hemisphere["lat"], southern_hemisphere["max temp"], marker="o")

# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemisphere["lat"], southern_hemisphere["max temp"])

# Get regression values
regress_values = southern_hemisphere["lat"] * slope + intercept
 
plt.plot(southern_hemisphere["lat"],regress_values,"r-")    

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
                                                                                                   

# Incorporate the other graph properties
plt.title("Southern City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (Farenheit)")
plt.xlabel("Latitude")
#plt.grid(True)
plt.annotate(line_eq,(-30,60),fontsize=15,color="red")  


# Print r square value
print(f"The r-squared is: {rvalue**2}")


# Save the figure
plt.savefig("TemperatureInSouthernCities.png")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.5854874931844887

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Build a scatter plot for each data type
plt.scatter(northern_hemisphere["lat"], northern_hemisphere["humidity"], marker="o")

# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemisphere["lat"], northern_hemisphere["humidity"])

# Get regression values
regress_values = northern_hemisphere["lat"] * slope + intercept
 
plt.plot(northern_hemisphere["lat"],regress_values,"r-")    

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
                                                                                                   

# Incorporate the other graph properties
plt.title("Northern City Latitude vs. Humidity")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
#plt.grid(True)
plt.annotate(line_eq,(50,40),fontsize=15,color="red")  


# Print r square value
print(f"The r-squared is: {rvalue**2}")


# Save the figure
plt.savefig("HumidityInNorthernCities.png")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.0792443225332199

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Build a scatter plot for each data type
plt.scatter(southern_hemisphere["lat"], southern_hemisphere["humidity"], marker="o")

# Perform a linear regression on humidity vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemisphere["lat"], southern_hemisphere["humidity"])

# Get regression values
regress_values = southern_hemisphere["lat"] * slope + intercept
 
plt.plot(southern_hemisphere["lat"],regress_values,"r-")    

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
                                                                                                   

# Incorporate the other graph properties
plt.title("Southern Cities Latitude vs. Humidity")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
#plt.grid(True)
plt.annotate(line_eq,(-25,50),fontsize=15,color="red")  


# Print r square value
print(f"The r-squared is: {rvalue**2}")


# Save the figure
plt.savefig("HumidityInSouthernCities.png")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.058681548398369664

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Build a scatter plot for each data type
plt.scatter(northern_hemisphere["lat"], northern_hemisphere["cloudiness"], marker="o")

# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemisphere["lat"], northern_hemisphere["cloudiness"])

# Get regression values
regress_values = northern_hemisphere["lat"] * slope + intercept
 
plt.plot(northern_hemisphere["lat"],regress_values,"r-")    

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
                                                                                                   

# Incorporate the other graph properties
plt.title("Northern City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
#plt.grid(True)
plt.annotate(line_eq,(20,25),fontsize=15,color="red")  


# Print r square value
print(f"The r-squared is: {rvalue**2}")


# Save the figure
plt.savefig("CloudinessInNorthernCities.png")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.043212540890370764

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Build a scatter plot for each data type
plt.scatter(southern_hemisphere["lat"], southern_hemisphere["cloudiness"], marker="o")

# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemisphere["lat"],southern_hemisphere["cloudiness"])

# Get regression values
regress_values = southern_hemisphere["lat"] * slope + intercept
 
plt.plot(southern_hemisphere["lat"],regress_values,"r-")    

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
                                                                                                   

# Incorporate the other graph properties
plt.title("Southern Cities Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
#plt.grid(True)
plt.annotate(line_eq,(-30,30),fontsize=15,color="red")  


# Print r square value
print(f"The r-squared is: {rvalue**2}")


# Save the figure
plt.savefig("CloudinessInSouthernCities.png")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.03478933358677128

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Build a scatter plot for each data type
plt.scatter(northern_hemisphere["lat"], northern_hemisphere["wind speed"], marker="o")

# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemisphere["lat"], northern_hemisphere["wind speed"])

# Get regression values
regress_values = northern_hemisphere["lat"] * slope + intercept
 
plt.plot(northern_hemisphere["lat"],regress_values,"r-")    

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
                                                                                                   

# Incorporate the other graph properties
plt.title("Northern City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
#plt.grid(True)
plt.annotate(line_eq,(20,25),fontsize=15,color="red")  


# Print r square value
print(f"The r-squared is: {rvalue**2}")


# Save the figure
plt.savefig("WindSpeedInNorthernCities.png")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.07810448973042575

# %%
#Northern city wind speed

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Build a scatter plot for each data type
plt.scatter(southern_hemisphere["lat"], southern_hemisphere["wind speed"], marker="o")

# Perform a linear regression on max temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemisphere["lat"], southern_hemisphere["wind speed"])

# Get regression values
regress_values = southern_hemisphere["lat"] * slope + intercept
 
plt.plot(southern_hemisphere["lat"],regress_values,"r-")    

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
                                                                                                   

# Incorporate the other graph properties
plt.title("Southern City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
#plt.grid(True)
plt.annotate(line_eq,(-22,20),fontsize=15,color="red")  


# Print r square value
print(f"The r-squared is: {rvalue**2}")


# Save the figure
plt.savefig("WindSpeedInSouthernCities.png")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.16242536104086258

# %%
#For southern cities the windspeed is lower in cities close to the equator versus those that are more towards the south.
